# %%
# %load_ext autoreload
# %autoreload 2

# %%
from prep_dataset import PrepDataset
from pathlib import Path

# %%
data_path = Path().resolve().parent / "data" / "forecasting_huggingface.csv"
assert data_path.exists()
obj = PrepDataset(data_path)

# %%
prompt = """Here is a forecasting question: Will advanced LIGO announce discovery of gravitational waves by Jan. 31 2016?

Here are the resolution criteria of the question: The Advanced Laser Interferometer Gravitational-Wave Observatory (LIGO) re-opened in mid September after a significant upgrade.
Designed with 10x greater sensitivity and a wider range of covered frequencies than the original LIGO, advanced LIGO should, according to its designers, have an "enhanced physics reach that during its first several hours of operation will exceed the integrated observations of the 1 year LIGO Science Run."
A full description of the experiment in gory detail can be found here.
Calculations of the expected detection rates suggest tens and potentially hundreds of detectable events per year under reasonable assumptions about neutron star and other types of binaries (and of course assuming General Relativity is correct, etc.)
Will the LIGO experiment publicly announce a 5-sigma (or equivalent) discovery of astrophysical gravitational waves by Jan 31, 2016?.

Based on the forecasting question and resolution criteria, generate low quality step-by-step reasoning to create a resolution. Output exactly 6 steps without an introduction or a conclusion."""

# %%
print(prompt)
# Out:
# Here is a forecasting question: Will advanced LIGO announce discovery of gravitational waves by Jan. 31 2016?
#
# Here are the resolution criteria of the question: The Advanced Laser Interferometer Gravitational-Wave Observatory (LIGO) re-opened in mid September after a significant upgrade.
# Designed with 10x greater sensitivity and a wider range of covered frequencies than the original LIGO, advanced LIGO should, according to its designers, have an "enhanced physics reach that during its first several hours of operation will exceed the integrated observations of the 1 year LIGO Science Run."
# A full description of the experiment in gory detail can be found here.
# Calculations of the expected detection rates suggest tens and potentially hundreds of detectable events per year under reasonable assumptions about neutron star and other types of binaries (and of course assuming General Relativity is correct, etc.)
# Will the LIGO experiment publicly announce a 5-sigma (or equivalent) discovery of astrophysical gravitational waves by Jan 31, 2016?.
#
# Based on the forecasting question and resolution criteria, generate low quality step-by-step reasoning to create a resolution. Output exactly 6 steps without an introduction or a conclusion.

# %% [markdown]
# ## Try 5 examples from HF train dataset

# %%
obj.df = obj.df.head(5)

# %%
obj.populate_df_general_prompts()

# %%
obj.populate_df_chosen_rejected()

# %%
obj.df
# Out:
#                                       extracted_urls  \
# 0                                                 []
# 1  ["https://sma.nasa.gov/LaunchVehicle/assets/sp...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                            url data_source  \
# 0  https://www.metaculus.com/api2/questions/1/   metaculus
# 1  https://www.metaculus.com/api2/questions/2/   metaculus
# 2  https://www.metaculus.com/api2/questions/5/   metaculus
# 3  https://www.metaculus.com/api2/questions/6/   metaculus
# 4  https://www.metaculus.com/api2/questions/7/   metaculus
#
#                                             question  date_close  resolution  \
# 0  Will advanced LIGO announce discovery of gravi...  2015-12-15         0.0
# 1  Will SpaceX successfully land a Falcon 9 rocke...  2016-01-30         0.0
# 2  Will Lockheed Martin and Skunkworks announce a...  2016-10-18         0.0
# 3  The FAA to soon open the door to commercial us...  2016-04-15         0.0
# 4  Will the cost of sequencing a human genome fal...  2016-02-15         0.0
#
#   question_type  is_resolved                                   background  \
# 0        binary         True  Not applicable/available for this question.
# 1        binary         True  Not applicable/available for this question.
# 2        binary         True  Not applicable/available for this question.
# 3        binary         True  Not applicable/available for this question.
# 4        binary         True  Not applicable/available for this question.
#
#                                community_predictions  date_begin  \
# 0  [["2015-10-02", 0.69], ["2015-11-03", 0.72], [...  2015-10-02
# 1  [["2015-10-26", 0.84], ["2015-12-03", 0.795], ...  2015-10-26
# 2  [["2016-01-04", 0.12], ["2016-01-05", 0.083], ...  2015-10-26
# 3  [["2015-12-09", 0.3], ["2015-12-09", 0.233], [...  2015-10-26
# 4  [["2015-11-12", 0.8], ["2015-11-12", 0.8], ["2...  2015-10-26
#
#      gpt_3p5_category date_resolve_at  \
# 0      Science & Tech      2016-02-01
# 1      Science & Tech      2016-02-28
# 2      Science & Tech      2019-04-23
# 3  Security & Defense      2016-06-16
# 4      Science & Tech      2017-12-01
#
#                                  resolution_criteria  \
# 0  The Advanced Laser Interferometer Gravitationa...
# 1  SpaceX's Falcon 9 rockets are designed to be r...
# 2  Lockheed Martin's Skunkworks has publicly anno...
# 3  The FAA has for several years been developing ...
# 4  The cost of sequencing a human genome has been...
#
#                                       general_prompt  \
# 0  Here is a forecasting question: Will advanced ...
# 1  Here is a forecasting question: Will SpaceX su...
# 2  Here is a forecasting question: Will Lockheed ...
# 3  Here is a forecasting question: The FAA to soo...
# 4  Here is a forecasting question: Will the cost ...
#
#                                        chosen_prompt  \
# 0  Here is a forecasting question: Will advanced ...
# 1  Here is a forecasting question: Will SpaceX su...
# 2  Here is a forecasting question: Will Lockheed ...
# 3  Here is a forecasting question: The FAA to soo...
# 4  Here is a forecasting question: Will the cost ...
#
#                                      rejected_prompt
# 0  Here is a forecasting question: Will advanced ...
# 1  Here is a forecasting question: Will SpaceX su...
# 2  Here is a forecasting question: Will Lockheed ...
# 3  Here is a forecasting question: The FAA to soo...
# 4  Here is a forecasting question: Will the cost ...

# %%
obj.get_all_gpt4_responses()

# %%
obj.df
# Out:
#                                       extracted_urls  \
# 0                                                 []
# 1  ["https://sma.nasa.gov/LaunchVehicle/assets/sp...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                            url data_source  \
# 0  https://www.metaculus.com/api2/questions/1/   metaculus
# 1  https://www.metaculus.com/api2/questions/2/   metaculus
# 2  https://www.metaculus.com/api2/questions/5/   metaculus
# 3  https://www.metaculus.com/api2/questions/6/   metaculus
# 4  https://www.metaculus.com/api2/questions/7/   metaculus
#
#                                             question  date_close  resolution  \
# 0  Will advanced LIGO announce discovery of gravi...  2015-12-15         0.0
# 1  Will SpaceX successfully land a Falcon 9 rocke...  2016-01-30         0.0
# 2  Will Lockheed Martin and Skunkworks announce a...  2016-10-18         0.0
# 3  The FAA to soon open the door to commercial us...  2016-04-15         0.0
# 4  Will the cost of sequencing a human genome fal...  2016-02-15         0.0
#
#   question_type  is_resolved                                   background  \
# 0        binary         True  Not applicable/available for this question.
# 1        binary         True  Not applicable/available for this question.
# 2        binary         True  Not applicable/available for this question.
# 3        binary         True  Not applicable/available for this question.
# 4        binary         True  Not applicable/available for this question.
#
#                                community_predictions  date_begin  \
# 0  [["2015-10-02", 0.69], ["2015-11-03", 0.72], [...  2015-10-02
# 1  [["2015-10-26", 0.84], ["2015-12-03", 0.795], ...  2015-10-26
# 2  [["2016-01-04", 0.12], ["2016-01-05", 0.083], ...  2015-10-26
# 3  [["2015-12-09", 0.3], ["2015-12-09", 0.233], [...  2015-10-26
# 4  [["2015-11-12", 0.8], ["2015-11-12", 0.8], ["2...  2015-10-26
#
#      gpt_3p5_category date_resolve_at  \
# 0      Science & Tech      2016-02-01
# 1      Science & Tech      2016-02-28
# 2      Science & Tech      2019-04-23
# 3  Security & Defense      2016-06-16
# 4      Science & Tech      2017-12-01
#
#                                  resolution_criteria  \
# 0  The Advanced Laser Interferometer Gravitationa...
# 1  SpaceX's Falcon 9 rockets are designed to be r...
# 2  Lockheed Martin's Skunkworks has publicly anno...
# 3  The FAA has for several years been developing ...
# 4  The cost of sequencing a human genome has been...
#
#                                       general_prompt  \
# 0  Here is a forecasting question: Will advanced ...
# 1  Here is a forecasting question: Will SpaceX su...
# 2  Here is a forecasting question: Will Lockheed ...
# 3  Here is a forecasting question: The FAA to soo...
# 4  Here is a forecasting question: Will the cost ...
#
#                                        chosen_prompt  \
# 0  Here is a forecasting question: Will advanced ...
# 1  Here is a forecasting question: Will SpaceX su...
# 2  Here is a forecasting question: Will Lockheed ...
# 3  Here is a forecasting question: The FAA to soo...
# 4  Here is a forecasting question: Will the cost ...
#
#                                      rejected_prompt  \
# 0  Here is a forecasting question: Will advanced ...
# 1  Here is a forecasting question: Will SpaceX su...
# 2  Here is a forecasting question: Will Lockheed ...
# 3  Here is a forecasting question: The FAA to soo...
# 4  Here is a forecasting question: Will the cost ...
#
#                                      chosen_response  \
# 0  1. **Understanding the Deadline and Operationa...
# 1  1. Review Past Performance: Analyze SpaceX's p...
# 2  1. Review the original timeline and promises m...
# 3  1. Identify the current regulatory status of u...
# 4  1. Start by reviewing the current cost of sequ...
#
#                                    rejected_response
# 0  1. Determine if LIGO is operational: Check if ...
# 1  1. Look at SpaceX's past attempts at landing F...
# 2  1. Start by searching for any news updates on ...
# 3  1. Look at the current date to determine how c...
# 4  1. Review the rate of decline in genome sequen...
