# %%
# %load_ext autoreload
# %autoreload 2

# %%
from prep_dataset import PrepDataset
from pathlib import Path

# %%
data_path = Path().resolve().parent / "data" / "train_hf_dataset.csv"
assert data_path.exists()
prepper = PrepDataset(data_path)

# %% [markdown]
# ## Try 5 examples from HF train dataset

# %%
prepper.populate_df_general_prompts()

# %%
prepper.populate_df_chosen_rejected()

# %%
prepper.df
# Out:
#                                          extracted_urls  \
# 0                                                    []
# 1     ["https://sma.nasa.gov/LaunchVehicle/assets/sp...
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 3757                                                 []
# 3758                                                 []
# 3759                                                 []
# 3760                                                 []
# 3761                                                 []
#
#                                                     url data_source  \
# 0           https://www.metaculus.com/api2/questions/1/   metaculus
# 1           https://www.metaculus.com/api2/questions/2/   metaculus
# 2           https://www.metaculus.com/api2/questions/5/   metaculus
# ...

# %%
prepper.get_all_gpt4_responses()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 prepper.get_all_gpt4_responses()
#
# File ~/local_desktop/stat165_final_proj/train/prep_dataset.py:94, in PrepDataset.get_all_gpt4_responses(self)
#      90 assert CHOSEN_PROMPT in self._get_df_columns() or REJECTED_PROMPT in self._get_df_columns()
#      91 assert not (
#      92     CHOSEN_RESPONSE in self._get_df_columns() or REJECTED_RESPONSE in self._get_df_columns()
#      93 ), f"Remove both columns {CHOSEN_RESPONSE} and {REJECTED_RESPONSE} from the df so they won't be overriden."
# ---> 94 chosen_responses = [self.prompt_gpt4_once(prompt) for prompt in self.df[CHOSEN_PROMPT]]
#      95 rejected_responses = [self.prompt_gpt4_once(prompt) for prompt in self.df[REJECTED_PROMPT]]
#      96 self.df[CHOSEN_RESPONSE] = chosen_responses
#
# ...

# %%
prepper.df
